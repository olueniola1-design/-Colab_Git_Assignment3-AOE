# %% [markdown]
# <a href="https://colab.research.google.com/github/olueniola1-design/-Colab_Git_Assignment3-AOE/blob/main/Lesson_3_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### **ATTENTION!!!**
# - **Place each section (1,2...) in one or more cells to keep the notebook organised**
# - **Complete the codes in the `TODO` sections**

# %%
# Python Library Management System

# Install required libraries (This should already exist in colab)
# !pip install requests

import pickle
import sqlite3
import requests

# 1. Data Types and Variables
book_title = "Python Programming"
book_quantity = 5
book_price = 29.99
is_available = True

print(f"Book: {book_title}, Quantity: {book_quantity}, Price: ${book_price}, Available: {is_available}")

# 2. Lists
books = ["Python Basics", "Advanced Python", "Data Science with Python"]

# TODO: Add two more books to the list
# books.append(...)
# books.insert(...)

print("Updated book list:", books)

# 3. Loops and range()
print("\nAvailable books:")
# TODO: Use a for loop and range() to print books with their indices
# for ... in range(...):
#     print(...)

# 4. User Input
new_book = input("Enter a new book title: ")
books.append(new_book)
print("Updated book list:", books)

# 5. Functions and Conditional Statements
def check_availability(book_name):
    # TODO: Check if the book is in the list and return True if available, False otherwise
    # if ...:
    #     return ...
    # else:
    #     return ...
    pass

# Test the function
print(f"Is 'Python Basics' available? {check_availability('Python Basics')}")

# 6. File I/O
def save_books_to_file(filename):
    with open(filename, 'w') as f:
        for book in books:
            f.write(f"{book}\n")

# TODO: Implement a function to read books from a file
# def read_books_from_file(filename):
#     ...

# Test file I/O
save_books_to_file("books.txt")
# !cat books.txt  # Display file contents in Colab

# 7. Pickle for serialization
def save_books_pickle(filename):
    with open(filename, 'wb') as f:
        pickle.dump(books, f)

# TODO: Implement a function to load books using pickle
# def load_books_pickle(filename):
#     ...

# Test pickle functions
save_books_pickle("books.pkl")
# Uncomment the next line after implementing load_books_pickle
# print("Books loaded from pickle:", load_books_pickle("books.pkl"))

# 8. SQLite Database Interaction
def create_books_table():
    conn = sqlite3.connect('library.db')
    cursor = conn.cursor()
    cursor.execute('''CREATE TABLE IF NOT EXISTS books
                      (id INTEGER PRIMARY KEY, title TEXT, quantity INTEGER)''')
    conn.commit()
    conn.close()

# TODO: Implement a function to add a book to the SQLite database
# def add_book_to_db(title, quantity):
#     ...

# Test database functions
create_books_table()
# Uncomment the next line after implementing add_book_to_db
# add_book_to_db("Python for Beginners", 10)

# 9. Web API Interaction (GitHub API)
def get_python_repos():
    url = "https://api.github.com/search/repositories"
    params = {"q": "language:python", "sort": "stars", "order": "desc"}
    response = requests.get(url, params=params)
    data = response.json()
    return [repo['name'] for repo in data['items'][:5]]

# Test API function
print("Top 5 Python repositories on GitHub:", get_python_repos())

print("\nLibrary Management System operations completed.")
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.12.14)
# Book: Python Programming, Quantity: 5, Price: $29.99, Available: True
# Updated book list: ['Python Basics', 'Advanced Python', 'Data Science with Python']
#
# Available books:
# Enter a new book title: Advanced Python
# Updated book list: ['Python Basics', 'Advanced Python', 'Data Science with Python', 'Advanced Python']
# Is 'Python Basics' available? None
# Python Basics
# Advanced Python
# Data Science with Python
# Advanced Python
# Top 5 Python repositories on GitHub: ['keras', 'rich', 'black', 'OpenHands', 'python-cheatsheet']
#
# Library Management System operations completed.

# %% [markdown]
# #TASKS
#
# Adding books to a list

# %%
# 2. Lists
books = ["Python Basics", "Advanced Python", "Data Science with Python"]

# >>> COMPLETED TODO: Add two more books to the list
books.append("Deep Learning Essentials")
books.insert(0, "Python for Beginners")

print("Updated book list:", books)
# Out:
# Updated book list: ['Python for Beginners', 'Python Basics', 'Advanced Python', 'Data Science with Python', 'Deep Learning Essentials']

# %% [markdown]
# ##Implementing a loop to print books with their indices

# %%
# 3. Loops and range()
print("\nAvailable books:")
# >>> COMPLETED TODO: Use a for loop and range() to print books with their indices
for i in range(len(books)):
    print(f"{i}: {books[i]}")
# Out:
# Available books:
# 0: Python for Beginners
# 1: Python Basics
# 2: Advanced Python
# 3: Data Science with Python
# 4: Deep Learning Essentials

# %% [markdown]
# ##Implementing a loop to print books with their indices

# %%
# 4. User Input (from notebook)
new_book = input("Python resource")
books.append("new_book")

print("Updated book list:", books)
# Out:
# Python resourceEffective Python
# Updated book list: ['Python for Beginners', 'Python Basics', 'Advanced Python', 'Data Science with Python', 'Deep Learning Essentials', 'new_book']

# %% [markdown]
# ##Creating a function to check book availability

# %%
# 5. Functions and Conditional Statements
def check_availability(book_name):
    # >>> COMPLETED TODO: Check if the book is in the list and return True if available, False otherwise
    if book_name in books:
        return "Book found in collection"
    else:
        return "Book not available"

# Test the function
print(f"Is 'Python Basics' available? {check_availability('Python Basics')}")
# Out:
# Is 'Python Basics' available? Book found in collection

# %% [markdown]
# ##Writing a function to read books from a file

# %%
# 6. File I/O
def save_books_to_file(filename):
    with open(filename, 'w') as f:
        for book in books:
            f.write(f"{book}\n")

# >>> COMPLETED TODO: Implement a function to read books from a file
def read_books_from_file(filename):
    with open(filename, 'r') as f:
        return [line.strip() for line in f.readlines()]

# Test file I/O
save_books_to_file("books.txt")
# !cat books.txt # Display file contents in Colab

# Test read function
print("Books read from file:", read_books_from_file("books.txt"))
# Out:
# Python for Beginners
# Python Basics
# Advanced Python
# Data Science with Python
# Deep Learning Essentials
# new_book
# Books read from file: ['Python for Beginners', 'Python Basics', 'Advanced Python', 'Data Science with Python', 'Deep Learning Essentials', 'new_book']

# %% [markdown]
# ##Implementing a function to load books using Pickle

# %%
import pickle

# 7. Pickle for serialization
def save_books_pickle(filename):
    with open(filename, 'wb') as f:
        pickle.dump(books, f)

# >>> COMPLETED TODO: Implement a function to load books using pickle
def load_books_pickle(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# Test pickle functions
save_books_pickle("books.pkl")
# Uncomment the next line after implementing load_books_pickle
print("Books loaded from pickle:", load_books_pickle("books.pkl"))
# Out:
# Books loaded from pickle: ['Python for Beginners', 'Python Basics', 'Advanced Python', 'Data Science with Python', 'Deep Learning Essentials', 'new_book']

# %% [markdown]
# ##Creating a function to add books to an SQLite database

# %%
import sqlite3

# 8. SQLite Database Interaction
def create_books_table():
    conn = sqlite3.connect('library.db')
    cursor = conn.cursor()
    cursor.execute('''CREATE TABLE IF NOT EXISTS books
                      (id INTEGER PRIMARY KEY, title TEXT, quantity INTEGER)''')
    conn.commit()
    conn.close()

# >>> COMPLETED TODO: Implement a function to add a book to the SQLite database
def add_book_to_db(title, quantity):
    conn = sqlite3.connect('library.db')
    cursor = conn.cursor()
    cursor.execute("INSERT INTO books (title, quantity) VALUES (?, ?)", (title, quantity))
    conn.commit()
    conn.close()

# Test database functions
create_books_table()
add_book_to_db("Python for Beginners", 10)

# %% [markdown]
# The Web API section

# %%
import requests

# 9. Web API Interaction (GitHub API)
def get_python_repos():
    url = "https://api.github.com/search/repositories"
    params = {"q": "language:python", "sort": "stars", "order": "desc"}
    response = requests.get(url, params=params)

    if response.ok:
        data = response.json()
        # Check if 'items' key exists before accessing it
        if 'items' in data:
            return [repo['name'] for repo in data['items'][:5]]
        else:
            print("API response did not contain 'items' key:", data)
            return []
    else:
        print(f"API request failed with status code {response.status_code}: {response.text}")
        return []

# Test API function
print("Top 5 Python repositories on GitHub:", get_python_repos())

print("\nLibrary Management System operations completed.")
# Out:
# API request failed with status code 403: {"message":"API rate limit exceeded for 34.21.92.173. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)","documentation_url":"https://docs.github.com/rest/overview/resources-in-the-rest-api#rate-limiting"}
#
# Top 5 Python repositories on GitHub: []
#
# Library Management System operations completed.

# %% [markdown]
# LINKS
#
# https://github.com/olueniola1-design/-Colab_Git_Assignment3-AOE/blob/main/Lesson_3_assignment.ipynb
#
#
# https://colab.research.google.com/drive/1D0IVuWBBhWng6swzPJonYTAyMRa1H5YB?usp=sharing
